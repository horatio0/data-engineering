# %%
import requests  # [+] HTTP 요청
from bs4 import BeautifulSoup  # [+] 웹스크래핑
import pandas as pd

# %%
# 1. User-Agent 설정
# 우리가 실제 크롬 브라우저를 사용하는 일반 사용자인 것처럼 서버를 속이는 '위장 신분증' 역할
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

search_keyword = '집'  # [+] 검색 키워드
url = f'https://search.naver.com/search.naver?where=news&query={search_keyword}'  # 검색한 웹페이지 주소

# %%
# 2. 페이지 요청 및 파싱
res = requests.get(url, headers=headers)  # [+] 네이버 서버에 페이지 정보 요청(GET)
res.raise_for_status() # 서버가 응답을 잘 주었는지 확인(정상 200, 페이지 없음 404 등)
soup = BeautifulSoup(res.text, 'html.parser')  # [+] BeautifulSoup 객체 생성

# %%
# 3. 질문자님이 찾은 클래스로 타겟팅 (띄어쓰기를 '.'으로 변경)
# [+] 찾고자 하는 HTML 태그 정의
target_class = "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1"
title_spans = soup.select(target_class) # [+] 조건에 맞는 모든 태그를 찾아 리스트로 저장

extracted_data = []

# %%
title_spans
# Out:
# [<span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">한동훈 "부산 북구에 <mark>집</mark> 구해"…보선 출마 사실상 공식화</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">오늘의<mark>집</mark>, 지난해 매출 3215억원....적자 전환</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">오픈AI 올트먼 <mark>집</mark>에 화염병 투척…문서엔 섬뜩 내용</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">한동훈 "부산 북구에 <mark>집</mark> 구했다"‥부산 북갑 출마 시사</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">오늘의<mark>집</mark>, 지난해 매출 3215억원…"창사이래 최고 성과"</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">"<mark>집</mark>에 가자" 늑구 발견한 신고자…애원에도 달아났다</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">"남의 <mark>집</mark> 주차장서 애정행각" 분노...렌터카 떠난 자리엔 민망한 쓰레기</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">국방부, '햄버거<mark>집</mark> 계엄 모의' 구삼회 등 파면·해임 중징계</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">한동훈 “부산 만덕에 <mark>집</mark> 구했다”…북구갑 출마 공식화</span>,
#  <span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1">강남 모친 <mark>집</mark>, 전세 끼고 샀다…‘가족 갭투자’로 22억 차익 거둔 한은...</span>]

# %%
# 4. 데이터 추출
for span in title_spans:
    # [+] 기사 제목 추출
    title = span.text.strip()
    
    # [+] 기사 링크 추출: 제목(span)을 클릭 가능하게 만드는 부모 <a> 태그를 역추적하여 찾음
    parent_a_tag = span.find_parent('a')
    link = parent_a_tag['href'] if parent_a_tag and parent_a_tag.has_attr('href') else "링크 없음"
    
    extracted_data.append({
        '제목': title,
        '링크': link
    })

# %%
# 5. [+] DataFrame으로 변환 및 확인
df = pd.DataFrame(extracted_data)
print(f"총 {len(df)}개의 기사를 추출했습니다.\n")
display(df)
# Out:
# 총 20개의 기사를 추출했습니다.
#                                              제목  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10              한동훈 "부산 북구에 집 구해"…보선 출마 사실상 공식화
# 11                 오늘의집, 지난해 매출 3215억원....적자 전환
# 12                 오픈AI 올트먼 집에 화염병 투척…문서엔 섬뜩 내용
# 13               한동훈 "부산 북구에 집 구했다"‥부산 북갑 출마 시사
# 14             오늘의집, 지난해 매출 3215억원…"창사이래 최고 성과"
# 15                 "집에 가자" 늑구 발견한 신고자…애원에도 달아났다
# 16     "남의 집 주차장서 애정행각" 분노...렌터카 떠난 자리엔 민망한 쓰레기
# 17            국방부, '햄버거집 계엄 모의' 구삼회 등 파면·해임 중징계
# 18                한동훈 “부산 만덕에 집 구했다”…북구갑 출마 공식화
# 19  강남 모친 집, 전세 끼고 샀다…‘가족 갭투자’로 22억 차익 거둔 한은...
#
#                                                    링크
# 0   https://www.yna.co.kr/view/AKR2026041309040000...
# 1         https://zdnet.co.kr/view/?no=20260414142409
# 2   https://news.sbs.co.kr/news/endPage.do?news_id...
# 3   https://imnews.imbc.com/news/2026/politics/art...
# 4   https://www.newsis.com/view/NISX20260414_00035...
# 5   http://www.edaily.co.kr/news/newspath.asp?news...
# 6   https://www.mt.co.kr/society/2026/04/14/202604...
# 7   https://news.tvchosun.com/site/data/html_dir/2...
# 8   https://www.seoul.co.kr/news/politics/2026/04/...
# 9   https://biz.heraldcorp.com/article/10716615?re...
# 10  https://www.yna.co.kr/view/AKR2026041309040000...
# 11        https://zdnet.co.kr/view/?no=20260414142409
# 12  https://news.sbs.co.kr/news/endPage.do?news_id...
# 13  https://imnews.imbc.com/news/2026/politics/art...
# 14  https://www.newsis.com/view/NISX20260414_00035...
# 15  http://www.edaily.co.kr/news/newspath.asp?news...
# 16  https://www.mt.co.kr/society/2026/04/14/202604...
# 17  https://news.tvchosun.com/site/data/html_dir/2...
# 18  https://www.seoul.co.kr/news/politics/2026/04/...
# 19  https://biz.heraldcorp.com/article/10716615?re...
